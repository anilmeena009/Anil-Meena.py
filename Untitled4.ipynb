# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("covid_toy.csv")
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'].mean()
# Out:
# 100.84444444444445

# %%
df['fever']=df['fever'].fillna(100)

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.loc[2:5,['age','fever','has_covid']]
# Out:
#    age  fever has_covid
# 2   42  101.0        No
# 3   31   98.0        No
# 4   65  101.0        No
# 5   84  100.0       Yes

# %%
df.iloc[2:5,[0,1,4]]
# Out:
#    age  gender     city
# 2   42    Male    Delhi
# 3   31  Female  Kolkata
# 4   65  Female   Mumbai

# %%
df2=df.copy()

# %%
df2.loc[2:5,['age','fever']]
# Out:
#    age  fever
# 2   42  101.0
# 3   31   98.0
# 4   65  101.0
# 5   84  100.0

# %%
df2.loc[2:5,['age','fever']]=100

# %%
df2.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2  100    Male  100.0  Mild    Delhi        No
# 3  100  Female  100.0  Mild  Kolkata        No
# 4  100  Female  100.0  Mild   Mumbai        No

# %%
df2['Gender']=df['gender'].map({'Male':0,'Female':1})

# %%
df2.head()
# Out:
#    age  gender  fever cough     city has_covid  Gender
# 0   60    Male  103.0  Mild  Kolkata        No       0
# 1   27    Male  100.0  Mild    Delhi       Yes       0
# 2  100    Male  100.0  Mild    Delhi        No       0
# 3  100  Female  100.0  Mild  Kolkata        No       1
# 4  100  Female  100.0  Mild   Mumbai        No       1

# %%
df2=df2.drop(columns=['Gender'])

# %%
df2.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2  100    Male  100.0  Mild    Delhi        No
# 3  100  Female  100.0  Mild  Kolkata        No
# 4  100  Female  100.0  Mild   Mumbai        No

# %%
df=df.rename(columns={
    'gender': 'Updated_gender',
    'fever': 'Latest_updated_fever'
})

# %%
df.head(2)
# Out:
#     age Latest_updated_fever has_covid Latest_updated_fever
# 0  60.0                103.0        No                  NaN
# 1  27.0                100.0       Yes                  NaN

# %%
df=df[['age','Latest_updated_fever' , 'has_covid']]

# %%
df
# Out:
#      age Latest_updated_fever Latest_updated_fever has_covid
# 0   60.0                103.0                  NaN        No
# 1   27.0                100.0                  NaN       Yes
# 2    NaN                101.0                 None      None
# 3    NaN                 98.0                 None      None
# 4    NaN                101.0                 None      None
# ..   ...                  ...                  ...       ...
# 95  12.0                104.0                  NaN        No
# 96  51.0                101.0                  NaN       Yes
# 97  20.0                101.0                  NaN        No
# 98   5.0                 98.0                  NaN        No
# 99  10.0                 98.0                  NaN       Yes
#
# [100 rows x 4 columns]

# %%
df2.loc[2:5,['age','fever','has_covid']]=None

# %%
df2.isnull().sum()
# Out:
# age          4
# gender       0
# fever        4
# cough        0
# city         0
# has_covid    4
# dtype: int64

# %%
df2.dropna()
# Out:
#      age  gender  fever   cough       city has_covid
# 0   60.0    Male  103.0    Mild    Kolkata        No
# 1   27.0    Male  100.0    Mild      Delhi       Yes
# 6   14.0    Male  101.0  Strong  Bangalore        No
# 7   20.0  Female  100.0  Strong     Mumbai       Yes
# 8   19.0  Female  100.0  Strong  Bangalore        No
# ..   ...     ...    ...     ...        ...       ...
# 95  12.0  Female  104.0    Mild  Bangalore        No
# 96  51.0  Female  101.0  Strong    Kolkata       Yes
# 97  20.0  Female  101.0    Mild  Bangalore        No
# 98   5.0  Female   98.0  Strong     Mumbai        No
# 99  10.0  Female   98.0  Strong    Kolkata       Yes
#
# [96 rows x 6 columns]
